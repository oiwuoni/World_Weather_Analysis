# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitutde combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count. 
len(cities)
# Out:
# 604

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datatime module from the datetime library. 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities. 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                         "Lat": city_lat, "Lng": city_lng, 
                         "Max Temp": city_max_temp, 
                         "Humidity": city_humidity, 
                         "Cloudiness": city_clouds, 
                         "Wind Speed": city_wind, 
                         "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city. 
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | salalah
# Processing Record 4 of Set 1 | los llanos de aridane
# Processing Record 5 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | pringsewu
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | ixtapa
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | inuvik
# Processing Record 15 of Set 1 | teya
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | nabire
# Processing Record 23 of Set 1 | lingsugur
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | itarema
# Processing Record 26 of Set 1 | cururupu
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | mynay
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | inhambane
# Processing Record 34 of Set 1 | camacha
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | saint-joseph
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | nhulunbuy
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | iralaya
# Processing Record 43 of Set 1 | ubinskoye
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | labuhan
# Processing Record 48 of Set 1 | sabang
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | belyy yar
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | yulara
# Processing Record 9 of Set 2 | seredka
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | hailar
# Processing Record 15 of Set 2 | cap malheureux
# Processing Record 16 of Set 2 | shache
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | naze
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | te anau
# Processing Record 22 of Set 2 | deputatskiy
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | opuwo
# Processing Record 27 of Set 2 | takaka
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 2 | cabras
# Processing Record 32 of Set 2 | xai-xai
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | seoul
# Processing Record 36 of Set 2 | yeppoon
# Processing Record 37 of Set 2 | olafsvik
# Processing Record 38 of Set 2 | svetlaya
# Processing Record 39 of Set 2 | agua verde
# Processing Record 40 of Set 2 | malkangiri
# Processing Record 41 of Set 2 | eyl
# Processing Record 42 of Set 2 | novorossiysk
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | lufilufi
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | aswan
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 50 of Set 2 | ushuaia
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | gainesville
# Processing Record 5 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 6 of Set 3 | raymondville
# Processing Record 7 of Set 3 | waddan
# Processing Record 8 of Set 3 | mumford
# Processing Record 9 of Set 3 | kimbe
# Processing Record 10 of Set 3 | the valley
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | douglas
# Processing Record 13 of Set 3 | dauriya
# Processing Record 14 of Set 3 | wuan
# Processing Record 15 of Set 3 | dali
# Processing Record 16 of Set 3 | campoverde
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | bonavista
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | suluq
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | kushmurun
# Processing Record 24 of Set 3 | dharmavaram
# Processing Record 25 of Set 3 | campos sales
# Processing Record 26 of Set 3 | itacarambi
# Processing Record 27 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | honningsvag
# Processing Record 31 of Set 3 | neiafu
# Processing Record 32 of Set 3 | berlevag
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | victoria
# Processing Record 35 of Set 3 | katangli
# Processing Record 36 of Set 3 | kawalu
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | lasa
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | alyangula
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | tornio
# Processing Record 45 of Set 3 | caravelas
# Processing Record 46 of Set 3 | roma
# Processing Record 47 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | banff
# Processing Record 50 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | nantucket
# Processing Record 3 of Set 4 | severnyy
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | bam
# Processing Record 6 of Set 4 | douentza
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | havelock
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | kharan
# Processing Record 11 of Set 4 | leh
# Processing Record 12 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | chuy
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | uruzgan
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | kamphaeng phet
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | litovko
# Processing Record 23 of Set 4 | magistralnyy
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | pingliang
# Processing Record 26 of Set 4 | cabra
# Processing Record 27 of Set 4 | mandla
# Processing Record 28 of Set 4 | quang ngai
# Processing Record 29 of Set 4 | bay saint louis
# Processing Record 30 of Set 4 | mende
# Processing Record 31 of Set 4 | sabha
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | tiznit
# Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | portland
# Processing Record 39 of Set 4 | hermosillo
# Processing Record 40 of Set 4 | kalianget
# Processing Record 41 of Set 4 | matara
# Processing Record 42 of Set 4 | eureka
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | lopez
# Processing Record 45 of Set 4 | shingu
# Processing Record 46 of Set 4 | zabid
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | johnson city
# Processing Record 49 of Set 4 | viloco
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | srednekolymsk
# Processing Record 2 of Set 5 | maumere
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | la sarre
# Processing Record 6 of Set 5 | manta
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 5 | humberto de campos
# Processing Record 10 of Set 5 | bria
# Processing Record 11 of Set 5 | sola
# Processing Record 12 of Set 5 | sao filipe
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | devrek
# Processing Record 17 of Set 5 | ribas do rio pardo
# Processing Record 18 of Set 5 | lubango
# Processing Record 19 of Set 5 | hoi an
# Processing Record 20 of Set 5 | hobyo
# Processing Record 21 of Set 5 | vertientes
# Processing Record 22 of Set 5 | borujan
# City not found. Skipping...
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | puerto narino
# Processing Record 25 of Set 5 | vostok
# Processing Record 26 of Set 5 | altay
# Processing Record 27 of Set 5 | donzdorf
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | dunedin
# Processing Record 30 of Set 5 | sao caetano de odivelas
# Processing Record 31 of Set 5 | yei
# Processing Record 32 of Set 5 | boende
# Processing Record 33 of Set 5 | ust-kuyga
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 5 | amparafaravola
# Processing Record 37 of Set 5 | praia
# Processing Record 38 of Set 5 | rorvik
# Processing Record 39 of Set 5 | turukhansk
# Processing Record 40 of Set 5 | fort wayne
# Processing Record 41 of Set 5 | mogadishu
# Processing Record 42 of Set 5 | makakilo city
# Processing Record 43 of Set 5 | finnsnes
# Processing Record 44 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 5 | sessa aurunca
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | jerez
# Processing Record 48 of Set 5 | samarai
# Processing Record 49 of Set 5 | airai
# Processing Record 50 of Set 5 | praya
# Processing Record 1 of Set 6 | linden
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | sakakah
# Processing Record 5 of Set 6 | alugan
# Processing Record 6 of Set 6 | praia da vitoria
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | berberati
# Processing Record 9 of Set 6 | isiro
# Processing Record 10 of Set 6 | nouadhibou
# Processing Record 11 of Set 6 | lokoja
# Processing Record 12 of Set 6 | asosa
# Processing Record 13 of Set 6 | canutama
# Processing Record 14 of Set 6 | boyuibe
# Processing Record 15 of Set 6 | vila velha
# Processing Record 16 of Set 6 | walvis bay
# Processing Record 17 of Set 6 | ouegoa
# Processing Record 18 of Set 6 | tavda
# Processing Record 19 of Set 6 | faanui
# Processing Record 20 of Set 6 | roald
# Processing Record 21 of Set 6 | nanortalik
# Processing Record 22 of Set 6 | mount gambier
# Processing Record 23 of Set 6 | bambous virieux
# Processing Record 24 of Set 6 | durant
# Processing Record 25 of Set 6 | koumac
# Processing Record 26 of Set 6 | saint-georges
# Processing Record 27 of Set 6 | sinnamary
# Processing Record 28 of Set 6 | chunoyar
# Processing Record 29 of Set 6 | quesnel
# Processing Record 30 of Set 6 | san andres
# Processing Record 31 of Set 6 | clyde river
# Processing Record 32 of Set 6 | tual
# Processing Record 33 of Set 6 | sangar
# Processing Record 34 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 6 | phangnga
# Processing Record 36 of Set 6 | plymouth
# Processing Record 37 of Set 6 | antofagasta
# Processing Record 38 of Set 6 | fare
# Processing Record 39 of Set 6 | poum
# Processing Record 40 of Set 6 | ystad
# Processing Record 41 of Set 6 | vincennes
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | hurghada
# Processing Record 46 of Set 6 | cardston
# Processing Record 47 of Set 6 | chatsu
# City not found. Skipping...
# Processing Record 48 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 6 | gondanglegi
# Processing Record 50 of Set 6 | broken hill
# Processing Record 1 of Set 7 | okhotsk
# Processing Record 2 of Set 7 | barrow
# Processing Record 3 of Set 7 | vila do maio
# Processing Record 4 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 7 | duz
# City not found. Skipping...
# Processing Record 6 of Set 7 | sakaiminato
# Processing Record 7 of Set 7 | tawau
# Processing Record 8 of Set 7 | banda aceh
# Processing Record 9 of Set 7 | alofi
# Processing Record 10 of Set 7 | fort wellington
# Processing Record 11 of Set 7 | pitimbu
# Processing Record 12 of Set 7 | haines junction
# Processing Record 13 of Set 7 | mfou
# Processing Record 14 of Set 7 | maragogi
# Processing Record 15 of Set 7 | sechura
# Processing Record 16 of Set 7 | marinette
# Processing Record 17 of Set 7 | dalbandin
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | gaogou
# Processing Record 23 of Set 7 | rajampet
# Processing Record 24 of Set 7 | hundorp
# Processing Record 25 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 26 of Set 7 | kincardine
# Processing Record 27 of Set 7 | malanje
# Processing Record 28 of Set 7 | longonjo
# Processing Record 29 of Set 7 | copiapo
# Processing Record 30 of Set 7 | sioux lookout
# Processing Record 31 of Set 7 | lima
# Processing Record 32 of Set 7 | linjiang
# Processing Record 33 of Set 7 | orotukan
# Processing Record 34 of Set 7 | kloulklubed
# Processing Record 35 of Set 7 | cayenne
# Processing Record 36 of Set 7 | kahului
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 39 of Set 7 | belaya gora
# Processing Record 40 of Set 7 | tombouctou
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | merke
# Processing Record 44 of Set 7 | chumikan
# Processing Record 45 of Set 7 | mazagao
# Processing Record 46 of Set 7 | marataizes
# Processing Record 47 of Set 7 | beyneu
# Processing Record 48 of Set 7 | bojnurd
# Processing Record 49 of Set 7 | leningradskiy
# Processing Record 50 of Set 7 | morondava
# Processing Record 1 of Set 8 | berbera
# Processing Record 2 of Set 8 | avera
# Processing Record 3 of Set 8 | kalulushi
# Processing Record 4 of Set 8 | gushikawa
# Processing Record 5 of Set 8 | loreto
# Processing Record 6 of Set 8 | alice springs
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | namibe
# Processing Record 9 of Set 8 | meulaboh
# Processing Record 10 of Set 8 | yangambi
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | hirara
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | dubti
# Processing Record 16 of Set 8 | rovaniemi
# Processing Record 17 of Set 8 | espoo
# Processing Record 18 of Set 8 | falam
# Processing Record 19 of Set 8 | saldanha
# Processing Record 20 of Set 8 | korla
# Processing Record 21 of Set 8 | hidrolandia
# Processing Record 22 of Set 8 | namatanai
# Processing Record 23 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 24 of Set 8 | araouane
# Processing Record 25 of Set 8 | banyo
# Processing Record 26 of Set 8 | havre
# Processing Record 27 of Set 8 | hami
# Processing Record 28 of Set 8 | bathsheba
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | soto la marina
# Processing Record 31 of Set 8 | anjangaon
# Processing Record 32 of Set 8 | police
# Processing Record 33 of Set 8 | vitim
# Processing Record 34 of Set 8 | muli
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | yemtsa
# Processing Record 37 of Set 8 | skjervoy
# Processing Record 38 of Set 8 | rio gallegos
# Processing Record 39 of Set 8 | cascais
# Processing Record 40 of Set 8 | kutum
# Processing Record 41 of Set 8 | flinders
# Processing Record 42 of Set 8 | kollam
# Processing Record 43 of Set 8 | porohy
# Processing Record 44 of Set 8 | cam ranh
# Processing Record 45 of Set 8 | awjilah
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | zonguldak
# Processing Record 48 of Set 8 | sao felix do xingu
# Processing Record 49 of Set 8 | lazarev
# Processing Record 50 of Set 8 | kamennomostskoye
# Processing Record 1 of Set 9 | carikar
# City not found. Skipping...
# Processing Record 2 of Set 9 | kasempa
# Processing Record 3 of Set 9 | vondrozo
# Processing Record 4 of Set 9 | plouzane
# Processing Record 5 of Set 9 | baykalsk
# Processing Record 6 of Set 9 | misratah
# Processing Record 7 of Set 9 | burica
# City not found. Skipping...
# Processing Record 8 of Set 9 | westerland
# Processing Record 9 of Set 9 | geraldton
# Processing Record 10 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 9 | verkhoyansk
# Processing Record 12 of Set 9 | bell ville
# Processing Record 13 of Set 9 | beloha
# Processing Record 14 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 9 | baran
# Processing Record 16 of Set 9 | seltso
# Processing Record 17 of Set 9 | lata
# Processing Record 18 of Set 9 | apricena
# Processing Record 19 of Set 9 | bestobe
# Processing Record 20 of Set 9 | salinopolis
# Processing Record 21 of Set 9 | maniitsoq
# Processing Record 22 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 9 | villazon
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | merritt
# Processing Record 30 of Set 9 | tatarsk
# Processing Record 31 of Set 9 | verkh-usugli
# Processing Record 32 of Set 9 | clearlake
# Processing Record 33 of Set 9 | tura
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | fort frances
# Processing Record 37 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 38 of Set 9 | kavaratti
# Processing Record 39 of Set 9 | san policarpo
# Processing Record 40 of Set 9 | nikel
# Processing Record 41 of Set 9 | cabedelo
# Processing Record 42 of Set 9 | half moon bay
# Processing Record 43 of Set 9 | medak
# Processing Record 44 of Set 9 | indian head
# Processing Record 45 of Set 9 | port augusta
# Processing Record 46 of Set 9 | synya
# Processing Record 47 of Set 9 | adrar
# Processing Record 48 of Set 9 | primero de enero
# Processing Record 49 of Set 9 | boddam
# Processing Record 50 of Set 9 | north branch
# Processing Record 1 of Set 10 | hovd
# Processing Record 2 of Set 10 | galle
# Processing Record 3 of Set 10 | palu
# Processing Record 4 of Set 10 | markova
# Processing Record 5 of Set 10 | vardo
# Processing Record 6 of Set 10 | maldonado
# Processing Record 7 of Set 10 | stornoway
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | mantamados
# Processing Record 10 of Set 10 | olimpia
# Processing Record 11 of Set 10 | marawi
# Processing Record 12 of Set 10 | nizwa
# Processing Record 13 of Set 10 | boyolangu
# Processing Record 14 of Set 10 | college
# Processing Record 15 of Set 10 | husavik
# Processing Record 16 of Set 10 | niquelandia
# Processing Record 17 of Set 10 | aquiraz
# Processing Record 18 of Set 10 | sarahan
# Processing Record 19 of Set 10 | kargasok
# Processing Record 20 of Set 10 | bulgan
# Processing Record 21 of Set 10 | ilam
# Processing Record 22 of Set 10 | constitucion
# Processing Record 23 of Set 10 | nakamura
# Processing Record 24 of Set 10 | taltal
# Processing Record 25 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 10 | olutanga
# Processing Record 27 of Set 10 | xichang
# Processing Record 28 of Set 10 | stellenbosch
# Processing Record 29 of Set 10 | vanimo
# Processing Record 30 of Set 10 | comodoro rivadavia
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | igurusi
# Processing Record 33 of Set 10 | afsin
# Processing Record 34 of Set 10 | tazovskiy
# Processing Record 35 of Set 10 | bayanday
# Processing Record 36 of Set 10 | inirida
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | grindavik
# Processing Record 39 of Set 10 | zyryanka
# Processing Record 40 of Set 10 | sawtell
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 10 | langham
# Processing Record 46 of Set 10 | elizabeth city
# Processing Record 47 of Set 10 | tafo
# Processing Record 48 of Set 10 | toora-khem
# Processing Record 49 of Set 10 | jiangyou
# Processing Record 50 of Set 10 | wenling
# Processing Record 1 of Set 11 | aizpute
# Processing Record 2 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | aykhal
# Processing Record 4 of Set 11 | koungou
# Processing Record 5 of Set 11 | asau
# Processing Record 6 of Set 11 | jinka
# Processing Record 7 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 11 | santa cruz
# Processing Record 9 of Set 11 | gualeguay
# Processing Record 10 of Set 11 | asyut
# Processing Record 11 of Set 11 | kabompo
# Processing Record 12 of Set 11 | santiago
# Processing Record 13 of Set 11 | dharchula
# Processing Record 14 of Set 11 | ilulissat
# Processing Record 15 of Set 11 | abalak
# Processing Record 16 of Set 11 | groningen
# Processing Record 17 of Set 11 | bilibino
# Processing Record 18 of Set 11 | xaxim
# Processing Record 19 of Set 11 | kirkuk
# Processing Record 20 of Set 11 | sadao
# Processing Record 21 of Set 11 | darnah
# Processing Record 22 of Set 11 | moissala
# Processing Record 23 of Set 11 | kamaishi
# Processing Record 24 of Set 11 | khorixas
# Processing Record 25 of Set 11 | kyshtovka
# Processing Record 26 of Set 11 | mangaluru
# Processing Record 27 of Set 11 | derzhavinsk
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | macuelizo
# Processing Record 30 of Set 11 | orlik
# Processing Record 31 of Set 11 | cumbitara
# Processing Record 32 of Set 11 | healdsburg
# Processing Record 33 of Set 11 | barentu
# Processing Record 34 of Set 11 | celestun
# Processing Record 35 of Set 11 | bella union
# Processing Record 36 of Set 11 | leiyang
# Processing Record 37 of Set 11 | isla mujeres
# Processing Record 38 of Set 11 | tall kayf
# Processing Record 39 of Set 11 | borogontsy
# Processing Record 40 of Set 11 | baykit
# Processing Record 41 of Set 11 | rantepao
# Processing Record 42 of Set 11 | calvinia
# Processing Record 43 of Set 11 | sorland
# Processing Record 44 of Set 11 | strezhevoy
# Processing Record 45 of Set 11 | arica
# Processing Record 46 of Set 11 | gao
# Processing Record 47 of Set 11 | amapa
# Processing Record 48 of Set 11 | kalabo
# Processing Record 49 of Set 11 | lisakovsk
# Processing Record 50 of Set 11 | brownwood
# Processing Record 1 of Set 12 | fairbanks
# Processing Record 2 of Set 12 | iquitos
# Processing Record 3 of Set 12 | novoagansk
# Processing Record 4 of Set 12 | grand gaube
# Processing Record 5 of Set 12 | talara
# Processing Record 6 of Set 12 | saint-gilles
# Processing Record 7 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 12 | wangdiphodrang
# City not found. Skipping...
# Processing Record 9 of Set 12 | kongolo
# Processing Record 10 of Set 12 | bridlington
# Processing Record 11 of Set 12 | belle fourche
# Processing Record 12 of Set 12 | tuy hoa
# Processing Record 13 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 14 of Set 12 | esso
# Processing Record 15 of Set 12 | neyshabur
# Processing Record 16 of Set 12 | tromso
# Processing Record 17 of Set 12 | kupang
# Processing Record 18 of Set 12 | brae
# Processing Record 19 of Set 12 | gejiu
# Processing Record 20 of Set 12 | imeni morozova
# Processing Record 21 of Set 12 | ginda
# Processing Record 22 of Set 12 | whitehorse
# Processing Record 23 of Set 12 | cockburn town
# Processing Record 24 of Set 12 | asfi
# Processing Record 25 of Set 12 | nattam
# Processing Record 26 of Set 12 | orebro
# Processing Record 27 of Set 12 | mineiros
# Processing Record 28 of Set 12 | moron
# Processing Record 29 of Set 12 | cesvaine
# Processing Record 30 of Set 12 | puck
# Processing Record 31 of Set 12 | zatoka
# Processing Record 32 of Set 12 | dubai
# Processing Record 33 of Set 12 | rincon
# Processing Record 34 of Set 12 | ishikari
# Processing Record 35 of Set 12 | sambava
# Processing Record 36 of Set 12 | baoshan
# Processing Record 37 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 38 of Set 12 | ambilobe
# Processing Record 39 of Set 12 | richards bay
# Processing Record 40 of Set 12 | nara
# Processing Record 41 of Set 12 | evensk
# Processing Record 42 of Set 12 | likoporia
# City not found. Skipping...
# Processing Record 43 of Set 12 | omboue
# Processing Record 44 of Set 12 | dwarka
# Processing Record 45 of Set 12 | laguna
# Processing Record 46 of Set 12 | drumnadrochit
# Processing Record 47 of Set 12 | camana
# Processing Record 48 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 12 | banfora
# Processing Record 50 of Set 12 | manica
# Processing Record 1 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | dangara
# Processing Record 4 of Set 13 | atka
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Provideniya  64.3833 -173.3000     10.83        55           0
# 1                   Hilo  19.7297 -155.0900     71.62        84          40
# 2                Salalah  17.0151   54.0924     80.69        54           0
# 3  Los Llanos De Aridane  28.6585  -17.9182     64.15        75          20
# 4           Puerto Ayora  -0.7393  -90.3518     84.16        84          52
# 5              Busselton -33.6500  115.3333     71.49        52          48
# 6             Bredasdorp -34.5322   20.0403     71.60        66           7
# 7                 Albany  42.6001  -73.9662     37.78        88          21
# 8              Pringsewu  -5.3582  104.9744     74.84        97         100
# 9               Luderitz -26.6481   15.1594     79.05        58          10
#
#    Wind Speed Country                 Date
# 0       15.46      RU  2022-03-10 16:13:45
# 1        5.75      US  2022-03-10 16:09:01
# 2        2.30      OM  2022-03-10 16:13:46
# 3        5.75      ES  2022-03-10 16:13:46
# 4        4.00      EC  2022-03-10 16:13:46
# 5        9.89      AU  2022-03-10 16:09:15
# 6       13.60      ZA  2022-03-10 16:13:47
# 7        2.80      US  2022-03-10 16:13:47
# 8        1.41      ID  2022-03-10 16:13:48
# 9       11.50      NA  2022-03-10 16:13:48

# %%
new_city_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_city_column_order]
city_data_df.head(10)
# Out:
#                     City Country                 Date      Lat       Lng  \
# 0            Provideniya      RU  2022-03-10 16:13:45  64.3833 -173.3000
# 1                   Hilo      US  2022-03-10 16:09:01  19.7297 -155.0900
# 2                Salalah      OM  2022-03-10 16:13:46  17.0151   54.0924
# 3  Los Llanos De Aridane      ES  2022-03-10 16:13:46  28.6585  -17.9182
# 4           Puerto Ayora      EC  2022-03-10 16:13:46  -0.7393  -90.3518
# 5              Busselton      AU  2022-03-10 16:09:15 -33.6500  115.3333
# 6             Bredasdorp      ZA  2022-03-10 16:13:47 -34.5322   20.0403
# 7                 Albany      US  2022-03-10 16:13:47  42.6001  -73.9662
# 8              Pringsewu      ID  2022-03-10 16:13:48  -5.3582  104.9744
# 9               Luderitz      NA  2022-03-10 16:13:48 -26.6481   15.1594
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     10.83        55           0       15.46
# 1     71.62        84          40        5.75
# 2     80.69        54           0        2.30
# 3     64.15        75          20        5.75
# 4     84.16        84          52        4.00
# 5     71.49        52          48        9.89
# 6     71.60        66           7       13.60
# 7     37.78        88          21        2.80
# 8     74.84        97         100        1.41
# 9     79.05        58          10       11.50

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV. 
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module. 
import time
# Build the scatter plot for latitude vs. max temperature. 
plt.scatter(lats, max_temp, edgecolor="black", linewidths=1, 
           marker="o", alpha=0.8, label="Cities")
# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure. 
plt.savefig("weather_data/Fig1.png")
# Show plot. 
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity. 
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure 
plt.savefig("weather_data/Fig2.png")
# Show plot. 
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness. 
plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure 
plt.savefig("weather_data/Fig3.png")
# Show plot. 
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed. 
plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure 
plt.savefig("weather_data/Fig4.png")
# Show plot. 
plt.show()

# %%
# Import linregress.
from scipy.stats import linregress
# Create a function to perform linear regression on the weather data and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_error) = linregress(x_values, y_values)
    # Calculate the regression line "y values" from the slope and intercept. 
    regress_values = x_values * slope + intercept 
    # Get the equation of the line. 
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line. 
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    # Annotate the text for the line equation. 
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                         Teya
# Country                        RU
# Date          2022-03-10 16:13:50
# Lat                       60.3778
# Lng                       92.6267
# Max Temp                   -20.69
# Humidity                      100
# Cloudiness                     73
# Wind Speed                   2.33
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#                     City Country                 Date      Lat       Lng  \
# 0            Provideniya      RU  2022-03-10 16:13:45  64.3833 -173.3000
# 1                   Hilo      US  2022-03-10 16:09:01  19.7297 -155.0900
# 2                Salalah      OM  2022-03-10 16:13:46  17.0151   54.0924
# 3  Los Llanos De Aridane      ES  2022-03-10 16:13:46  28.6585  -17.9182
# 7                 Albany      US  2022-03-10 16:13:47  42.6001  -73.9662
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     10.83        55           0       15.46
# 1     71.62        84          40        5.75
# 2     80.69        54           0        2.30
# 3     64.15        75          20        5.75
# 7     37.78        88          21        2.80

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \ for Maximum Temperature',
                      'Max Temp', (10,40))

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature',
                      'Max Temp', (-50,90))

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \ for % Humidity',
                      '% Humidity', (40,10))

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity',
                      '% Humidity', (-50,15))

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness',
                      '% Cloudiness', (10,55))

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness',
                      '% Cloudiness', (-50,60))

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed',
                      'Wind Speed', (40,35))

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function. 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southen Hemisphere \n for Wind Speed',
                      'Wind Speed', (-20,20))
